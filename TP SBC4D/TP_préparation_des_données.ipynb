# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('HDR_2007-2008_Table 26.xlsx')
df.head(12)
# Out:
#                    Unnamed: 0 Unnamed: 1                       Unnamed: 2  \
# 0                         NaN        NaN  … protecting personal security…
# 1   26 Refugees and armaments        NaN                              NaN
# 2                         NaN        NaN                              NaN
# 3                         NaN        NaN                              NaN
# 4                         NaN        NaN                              NaN
# 5                         NaN        NaN                              NaN
# 6                         NaN        NaN                              NaN
# 7                         NaN        NaN                              NaN
# 8                         NaN        NaN                              NaN
# 9                         NaN        NaN                              NaN
# 10                   HDI rank        NaN                              NaN
# 11                        NaN        NaN                              NaN
#
#                                            Unnamed: 3 Unnamed: 4  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                                 NaN        NaN
# 10  Internally displaced peoplea\n(thousands)     ...        NaN
# 11                                                NaN        NaN
#
#                                   Unnamed: 5 Unnamed: 6  \
# 0                                        NaN        NaN
# 1                                        NaN        NaN
# 2                                        NaN        NaN
# 3                                        NaN        NaN
# 4                                        NaN        NaN
# 5                                        NaN        NaN
# 6                                        NaN        NaN
# 7                                        NaN        NaN
# 8                                        NaN        NaN
# 9                                        NaN        NaN
# 10                                 Refugees         NaN
# 11  By country of asylum\n(thousands)\n2006e        NaN
#
#                                     Unnamed: 7 Unnamed: 8  \
# 0                                          NaN        NaN
# 1                                          NaN        NaN
# 2                                          NaN        NaN
# 3                                          NaN        NaN
# 4                                          NaN        NaN
# 5                                          NaN        NaN
# 6                                          NaN        NaN
# 7                                          NaN        NaN
# 8                                          NaN        NaN
# 9                                          NaN        NaN
# 10                                         NaN        NaN
# 11  By country of originc\n(thousands) \n2006e        NaN
#
#                                      Unnamed: 9     ...      \
# 0                                           NaN     ...
# 1                                           NaN     ...
# 2                                           NaN     ...
# 3                                           NaN     ...
# 4                                           NaN     ...
# 5                                           NaN     ...
# 6                                           NaN     ...
# 7                                           NaN     ...
# 8                                           NaN     ...
# 9   Conventional arms transfersb\n(1990 prices)     ...
# 10                      Imports\n(US$ millions)     ...
# 11                                         1996     ...
#
#                Unnamed: 15 Unnamed: 16         Unnamed: 17 Unnamed: 18  \
# 0                      NaN         NaN                 NaN         NaN
# 1                      NaN         NaN                 NaN         NaN
# 2                      NaN         NaN                 NaN         NaN
# 3                      NaN         NaN                 NaN         NaN
# 4                      NaN         NaN                 NaN         NaN
# 5                      NaN         NaN                 NaN         NaN
# 6                      NaN         NaN                 NaN         NaN
# 7                      NaN         NaN                 NaN         NaN
# 8                      NaN         NaN                 NaN         NaN
# 9                      NaN         NaN  Total armed forces         NaN
# 10                     NaN         NaN     Thousands\n2007         NaN
# 11  Shared\n(%)  \n2002-06         NaN                 NaN         NaN
#
#                    Unnamed: 19 Unnamed: 20  Unnamed: 21 Unnamed: 22  \
# 0                          NaN         NaN          NaN         NaN
# 1                          NaN         NaN          NaN         NaN
# 2                          NaN         NaN          NaN         NaN
# 3                          NaN         NaN          NaN         NaN
# 4                          NaN         NaN          NaN         NaN
# 5                          NaN         NaN          NaN         NaN
# 6                          NaN         NaN          NaN         NaN
# 7                          NaN         NaN          NaN         NaN
# 8                          NaN         NaN          NaN         NaN
# 9                          NaN         NaN          NaN         NaN
# 10  Index \n(1985 = 100)\n2007         NaN          NaN         NaN
# 11                         NaN         NaN          NaN         NaN
#
#    Unnamed: 23 Unnamed: 24
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
#
# [12 rows x 25 columns]

# %%
df = pd.read_excel('HDR_2007-2008_Table 26.xlsx', header = 9)
df = df.dropna(how="all", axis=1)
df = df.dropna(how="all", axis=0).reset_index(drop=True)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1  \
# 0                     NaN        NaN
# 1                HDI rank        NaN
# 2                     NaN        NaN
# 3  HIGH HUMAN DEVELOPMENT        NaN
# 4                       1    Iceland
# 5                       2     Norway
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN
# 1  Internally displaced peoplea\n(thousands)     ...        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                 ..        NaN
# 5                                                 ..        NaN
#
#                                  Unnamed: 5 Unnamed: 6  \
# 0                                       NaN        NaN
# 1                                 Refugees         NaN
# 2  By country of asylum\n(thousands)\n2006e        NaN
# 3                                       NaN        NaN
# 4                                       (.)        NaN
# 5                                        43        NaN
#
#                                    Unnamed: 7 Unnamed: 8  \
# 0                                         NaN        NaN
# 1                                         NaN        NaN
# 2  By country of originc\n(thousands) \n2006e        NaN
# 3                                         NaN        NaN
# 4                                         (.)        NaN
# 5                                          ..        NaN
#
#                                     Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  Conventional arms transfersb\n(1990 prices)         NaN         NaN
# 1                      Imports\n(US$ millions)         NaN         NaN
# 2                                         1996         NaN        2006
# 3                                          NaN         NaN         NaN
# 4                                           ..         NaN          ..
# 5                                          183         NaN         501
#
#   Unnamed: 12         Unnamed: 13 Unnamed: 14             Unnamed: 15  \
# 0         NaN                 NaN         NaN                     NaN
# 1         NaN           Exports\n         NaN                     NaN
# 2         NaN  US$ millions  2006         NaN  Shared\n(%)  \n2002-06
# 3         NaN                 NaN         NaN                     NaN
# 4         NaN                  ..         NaN                      ..
# 5         NaN                   2         NaN                     (.)
#
#           Unnamed: 17 Unnamed: 18                 Unnamed: 19
# 0  Total armed forces         NaN                         NaN
# 1     Thousands\n2007         NaN  Index \n(1985 = 100)\n2007
# 2                 NaN         NaN                         NaN
# 3                 NaN         NaN                         NaN
# 4                   0         NaN                          ..
# 5                  23         NaN                          62

# %%
columns = []
for c in df.columns:
    columns.append([str(v) for v in df[c][:3] if pd.notnull(v)])
columns
# Out:
# [['HDI rank'],
#  [],
#  ['Internally displaced peoplea\n(thousands)                               2006e'],
#  [],
#  ['Refugees ', 'By country of asylum\n(thousands)\n2006e'],
#  [],
#  ['By country of originc\n(thousands) \n2006e'],
#  [],
#  ['Conventional arms transfersb\n(1990 prices)',
#   'Imports\n(US$ millions)',
#   '1996'],
#  [],
#  ['2006'],
#  [],
#  ['Exports\n', 'US$ millions  2006'],
#  [],
#  ['Shared\n(%)  \n2002-06'],
#  ['Total armed forces', 'Thousands\n2007'],
#  [],
#  ['Index \n(1985 = 100)\n2007']]

# %%
columns = [
    "HDI rank",
    "Country",
    "Internally displaced peoplea(thousands)2006e ",
    "Reference 1",
    "Refugees By country of asylum(thousands)2006e",
        "Reference 2",
    "Refugees By country of originc(thousands) 2006e",
    "Reference 3",
    "Conventional arms transfersb(1990 prices) Imports (US$ millions) 1996",
    "Reference 4",
    "2006",
    "Reference 5",
    "Conventional arms Exports US$ millions  2006",
    "Reference 6",
    "Shared\n(%)  2002-06",   
    "Total armed forces Thousands2007", 
    "Reference 7",
    "Total armed forces Index (1985 = 100)2007"
]
df.columns = columns
df = df.drop(np.arange(5), axis=0).reset_index(drop=True)
df.head()
# Out:
#   HDI rank      Country Internally displaced peoplea(thousands)2006e   \
# 0        7  Switzerland                                            ..
# 1        8        Japan                                            ..
# 2        9  Netherlands                                            ..
# 3       10       France                                            ..
# 4       11      Finland                                            ..
#
#   Reference 1 Refugees By country of asylum(thousands)2006e Reference 2  \
# 0         NaN                                            49         NaN
# 1         NaN                                             2         NaN
# 2         NaN                                           101         NaN
# 3         NaN                                           146         NaN
# 4         NaN                                            12         NaN
#
#   Refugees By country of originc(thousands) 2006e Reference 3  \
# 0                                             (.)         NaN
# 1                                             (.)         NaN
# 2                                             (.)         NaN
# 3                                             (.)         NaN
# 4                                             (.)         NaN
#
#   Conventional arms transfersb(1990 prices) Imports (US$ millions) 1996  \
# 0                                                187
# 1                                                813
# 2                                                181
# 3                                                 28
# 4                                                605
#
#   Reference 4 2006 Reference 5 Conventional arms Exports US$ millions  2006  \
# 0         NaN   72         NaN                                          144
# 1         NaN  400         NaN                                            0
# 2         NaN  171         NaN                                        1,481
# 3         NaN  121         NaN                                        1,557
# 4         NaN   84         NaN                                           31
#
#   Reference 6 Shared\n(%)  2002-06 Total armed forces Thousands2007  \
# 0         NaN                    1                                4
# 1         NaN                  (.)                              240
# 2         NaN                    3                               53
# 3         NaN                    8                              255
# 4         NaN                  (.)                               29
#
#   Reference 7 Total armed forces Index (1985 = 100)2007
# 0         NaN                                        ..
# 1         NaN                                        99
# 2         NaN                                        50
# 3         NaN                                        55
# 4         NaN                                        79

# %%
df.tail(30)
# Out:
#     HDI rank                           Country  \
# 91        97                            Guyana
# 92        98                        Azerbaijan
# 93        99                         Sri Lanka
# 94       100                          Maldives
# 95       101                           Jamaica
# 96       102                        Cape Verde
# 97       103                       El Salvador
# 98       104                           Algeria
# 99       105                          Viet Nam
# 100      106  Occupied Palestinian Territories
# 101      107                         Indonesia
# 102      108              Syrian Arab Republic
# 103      109                      Turkmenistan
# 104      110                         Nicaragua
# 105      111                           Moldova
# 106      112                             Egypt
# 107      113                        Uzbekistan
# 108      114                          Mongolia
# 109      115                          Honduras
# 110      116                        Kyrgyzstan
# 111      117                           Bolivia
# 112      118                         Guatemala
# 113      119                             Gabon
# 114      120                           Vanuatu
# 115      121                      South Africa
# 116      122                        Tajikistan
# 117      123             Sao Tome and Principe
# 118      124                          Botswana
# 119      125                           Namibia
# 120      126                           Morocco
#
#     Internally displaced peoplea(thousands)2006e  Reference 1  \
# 91                                             ..         NaN
# 92                                        579-687           i
# 93                                            600           g
# 94                                             ..         NaN
# 95                                             ..         NaN
# 96                                             ..         NaN
# 97                                             ..         NaN
# 98                                          1,000           g
# 99                                             ..         NaN
# 100                                         25-57         g,k
# 101                                       150-250         NaN
# 102                                           305           g
# 103                                             0         NaN
# 104                                            ..         NaN
# 105                                            ..         NaN
# 106                                            ..         NaN
# 107                                             3           g
# 108                                            ..         NaN
# 109                                            ..         NaN
# 110                                            ..         NaN
# 111                                            ..         NaN
# 112                                           242           g
# 113                                            ..         NaN
# 114                                            ..         NaN
# 115                                            ..         NaN
# 116                                            ..         NaN
# 117                                            ..         NaN
# 118                                            ..         NaN
# 119                                            ..         NaN
# 120                                            ..         NaN
#
#     Refugees By country of asylum(thousands)2006e Reference 2  \
# 91                                             ..         NaN
# 92                                              3         NaN
# 93                                            (.)         NaN
# 94                                             ..         NaN
# 95                                             ..         NaN
# 96                                             ..         NaN
# 97                                            (.)         NaN
# 98                                             94           j
# 99                                              2         NaN
# 100                                            ..         NaN
# 101                                           (.)         NaN
# 102                                           702         NaN
# 103                                             1         NaN
# 104                                           (.)         NaN
# 105                                           (.)         NaN
# 106                                            88         NaN
# 107                                             1         NaN
# 108                                           (.)         NaN
# 109                                           (.)         NaN
# 110                                           (.)         NaN
# 111                                             1         NaN
# 112                                           (.)         NaN
# 113                                             8         NaN
# 114                                            ..         NaN
# 115                                            35         NaN
# 116                                             1         NaN
# 117                                            ..         NaN
# 118                                             3         NaN
# 119                                             5         NaN
# 120                                             1         NaN
#
#     Refugees By country of originc(thousands) 2006e Reference 3  \
# 91                                                1         NaN
# 92                                              126         NaN
# 93                                              117         NaN
# 94                                              (.)         NaN
# 95                                                1         NaN
# 96                                              (.)         NaN
# 97                                                6         NaN
# 98                                                8         NaN
# 99                                              374         NaN
# 100                                             334         NaN
# 101                                              35         NaN
# 102                                              12         NaN
# 103                                               1         NaN
# 104                                               2         NaN
# 105                                              12         NaN
# 106                                               8         NaN
# 107                                               9         NaN
# 108                                               1         NaN
# 109                                               1         NaN
# 110                                               2         NaN
# 111                                             (.)         NaN
# 112                                               7         NaN
# 113                                             (.)         NaN
# 114                                              ..         NaN
# 115                                               1         NaN
# 116                                               1         NaN
# 117                                             (.)         NaN
# 118                                             (.)         NaN
# 119                                               1         NaN
# 120                                               5         NaN
#
#     Conventional arms transfersb(1990 prices) Imports (US$ millions) 1996  \
# 91                                                   0
# 92                                                   0
# 93                                                 152
# 94                                                   0
# 95                                                   0
# 96                                                   0
# 97                                                   3
# 98                                                  87
# 99                                                 207
# 100                                                  9
# 101                                                435
# 102                                                 21
# 103                                                  0
# 104                                                 ..
# 105                                                  0
# 106                                                986
# 107                                                  0
# 108                                                 ..
# 109                                                 ..
# 110                                                  0
# 111                                                  0
# 112                                                  0
# 113                                                  0
# 114                                                 ..
# 115                                                 38
# 116                                                  0
# 117                                                 ..
# 118                                                 29
# 119                                                  0
# 120                                                 86
#
#     Reference 4 2006 Reference 5 Conventional arms Exports US$ millions  2006  \
# 91          NaN    0         NaN                                           ..
# 92          NaN    0         NaN                                           ..
# 93          NaN   20         NaN                                           ..
# 94          NaN    0         NaN                                           ..
# 95          NaN   25         NaN                                           ..
# 96          NaN    0         NaN                                           ..
# 97          NaN    0         NaN                                           ..
# 98          NaN  173         NaN                                           ..
# 99          NaN  179         NaN                                           ..
# 100         NaN    0         NaN                                           ..
# 101         NaN   54         NaN                                            8
# 102         NaN    9         NaN                                            3
# 103         NaN    0         NaN                                           ..
# 104         NaN   ..         NaN                                            0
# 105         NaN    0         NaN                                            0
# 106         NaN  526         NaN                                            0
# 107         NaN    0         NaN                                            0
# 108         NaN   ..         NaN                                           ..
# 109         NaN   ..         NaN                                           ..
# 110         NaN    1         NaN                                            0
# 111         NaN   26         NaN                                           ..
# 112         NaN    0         NaN                                           ..
# 113         NaN   63         NaN                                           ..
# 114         NaN   ..         NaN                                           ..
# 115         NaN  862         NaN                                          115
# 116         NaN   13         NaN                                           ..
# 117         NaN   ..         NaN                                           ..
# 118         NaN    0         NaN                                           ..
# 119         NaN    0         NaN                                           ..
# 120         NaN   49         NaN                                           ..
#
#     Reference 6 Shared\n(%)  2002-06 Total armed forces Thousands2007  \
# 91          NaN                   ..                                1
# 92          NaN                   ..                               67
# 93          NaN                   ..                              151
# 94          NaN                   ..                               ..
# 95          NaN                   ..                                3
# 96          NaN                   ..                                1
# 97          NaN                   ..                               16
# 98          NaN                   ..                              138
# 99          NaN                   ..                              455
# 100         NaN                   ..                               ..
# 101         NaN                  (.)                              302
# 102         NaN                  (.)                              308
# 103         NaN                   ..                               26
# 104         NaN                  (.)                               14
# 105         NaN                  (.)                                7
# 106         NaN                  (.)                              469
# 107         NaN                    1                               55
# 108         NaN                   ..                                9
# 109         NaN                   ..                               12
# 110         NaN                  (.)                               13
# 111         NaN                   ..                               46
# 112         NaN                   ..                               16
# 113         NaN                   ..                                5
# 114         NaN                   ..                               ..
# 115         NaN                  (.)                               62
# 116         NaN                   ..                                8
# 117         NaN                   ..                               ..
# 118         NaN                   ..                                9
# 119         NaN                   ..                                9
# 120         NaN                   ..                              201
#
#     Reference 7 Total armed forces Index (1985 = 100)2007
# 91          NaN                                        15
# 92          NaN                                        ..
# 93          NaN                                       699
# 94          NaN                                        ..
# 95          NaN                                       143
# 96          NaN                                        13
# 97          NaN                                        38
# 98          NaN                                        81
# 99          NaN                                        44
# 100         NaN                                        ..
# 101         NaN                                       109
# 102         NaN                                        77
# 103         NaN                                        ..
# 104         NaN                                        22
# 105         NaN                                        ..
# 106         NaN                                       105
# 107         NaN                                        ..
# 108         NaN                                        27
# 109         NaN                                        72
# 110         NaN                                        ..
# 111         NaN                                       167
# 112         NaN                                        50
# 113         NaN                                       208
# 114         NaN                                        ..
# 115         NaN                                        58
# 116         NaN                                        ..
# 117         NaN                                        ..
# 118         NaN                                       225
# 119         NaN                                        ..
# 120         NaN                                       135

# %%
df = df.drop(np.arange(126,len(df)), axis=0).reset_index(drop=True)df.tail(50)

# %%
df.tail(50)
# Out:
#     HDI rank                           Country  \
# 71        77                             Samoa
# 72        78                          Thailand
# 73        79                Dominican Republic
# 74        80                            Belize
# 75        81                             China
# 76        82                           Grenada
# 77        83                           Armenia
# 78        84                            Turkey
# 79        85                          Suriname
# 80        86                            Jordan
# 81        87                              Peru
# 82        88                           Lebanon
# 83        89                           Ecuador
# 84        90                       Philippines
# 85        91                           Tunisia
# 86        92                              Fiji
# 87        93  Saint Vincent and the Grenadines
# 88        94        Iran (Islamic Republic of)
# 89        95                          Paraguay
# 90        96                           Georgia
# 91        97                            Guyana
# 92        98                        Azerbaijan
# 93        99                         Sri Lanka
# 94       100                          Maldives
# 95       101                           Jamaica
# 96       102                        Cape Verde
# 97       103                       El Salvador
# 98       104                           Algeria
# 99       105                          Viet Nam
# 100      106  Occupied Palestinian Territories
# 101      107                         Indonesia
# 102      108              Syrian Arab Republic
# 103      109                      Turkmenistan
# 104      110                         Nicaragua
# 105      111                           Moldova
# 106      112                             Egypt
# 107      113                        Uzbekistan
# 108      114                          Mongolia
# 109      115                          Honduras
# 110      116                        Kyrgyzstan
# 111      117                           Bolivia
# 112      118                         Guatemala
# 113      119                             Gabon
# 114      120                           Vanuatu
# 115      121                      South Africa
# 116      122                        Tajikistan
# 117      123             Sao Tome and Principe
# 118      124                          Botswana
# 119      125                           Namibia
# 120      126                           Morocco
#
#     Internally displaced peoplea(thousands)2006e  Reference 1  \
# 71                                             ..         NaN
# 72                                             ..         NaN
# 73                                             ..         NaN
# 74                                             ..         NaN
# 75                                             ..         NaN
# 76                                             ..         NaN
# 77                                              8           g
# 78                                       954-1201         NaN
# 79                                             ..         NaN
# 80                                             ..         NaN
# 81                                             60           g
# 82                                        216-800         NaN
# 83                                             ..         NaN
# 84                                            120         NaN
# 85                                             ..         NaN
# 86                                             ..         NaN
# 87                                             ..         NaN
# 88                                             ..         NaN
# 89                                             ..         NaN
# 90                                        222-241         NaN
# 91                                             ..         NaN
# 92                                        579-687           i
# 93                                            600           g
# 94                                             ..         NaN
# 95                                             ..         NaN
# 96                                             ..         NaN
# 97                                             ..         NaN
# 98                                          1,000           g
# 99                                             ..         NaN
# 100                                         25-57         g,k
# 101                                       150-250         NaN
# 102                                           305           g
# 103                                             0         NaN
# 104                                            ..         NaN
# 105                                            ..         NaN
# 106                                            ..         NaN
# 107                                             3           g
# 108                                            ..         NaN
# 109                                            ..         NaN
# 110                                            ..         NaN
# 111                                            ..         NaN
# 112                                           242           g
# 113                                            ..         NaN
# 114                                            ..         NaN
# 115                                            ..         NaN
# 116                                            ..         NaN
# 117                                            ..         NaN
# 118                                            ..         NaN
# 119                                            ..         NaN
# 120                                            ..         NaN
#
#     Refugees By country of asylum(thousands)2006e Reference 2  \
# 71                                             ..         NaN
# 72                                            133         NaN
# 73                                             ..         NaN
# 74                                            (.)         NaN
# 75                                            301         NaN
# 76                                             ..         NaN
# 77                                            114         NaN
# 78                                              3         NaN
# 79                                             ..         NaN
# 80                                            500         NaN
# 81                                              1         NaN
# 82                                             20         NaN
# 83                                             12         NaN
# 84                                            (.)         NaN
# 85                                            (.)         NaN
# 86                                             ..         NaN
# 87                                             ..         NaN
# 88                                            968         NaN
# 89                                            (.)         NaN
# 90                                              1         NaN
# 91                                             ..         NaN
# 92                                              3         NaN
# 93                                            (.)         NaN
# 94                                             ..         NaN
# 95                                             ..         NaN
# 96                                             ..         NaN
# 97                                            (.)         NaN
# 98                                             94           j
# 99                                              2         NaN
# 100                                            ..         NaN
# 101                                           (.)         NaN
# 102                                           702         NaN
# 103                                             1         NaN
# 104                                           (.)         NaN
# 105                                           (.)         NaN
# 106                                            88         NaN
# 107                                             1         NaN
# 108                                           (.)         NaN
# 109                                           (.)         NaN
# 110                                           (.)         NaN
# 111                                             1         NaN
# 112                                           (.)         NaN
# 113                                             8         NaN
# 114                                            ..         NaN
# 115                                            35         NaN
# 116                                             1         NaN
# 117                                            ..         NaN
# 118                                             3         NaN
# 119                                             5         NaN
# 120                                             1         NaN
#
#     Refugees By country of originc(thousands) 2006e Reference 3  \
# 71                                               ..         NaN
# 72                                                3         NaN
# 73                                              (.)         NaN
# 74                                              (.)         NaN
# 75                                              141         NaN
# 76                                              (.)         NaN
# 77                                               15         NaN
# 78                                              227         NaN
# 79                                              (.)         NaN
# 80                                                2         NaN
# 81                                                7         NaN
# 82                                               12         NaN
# 83                                                1         NaN
# 84                                                1         NaN
# 85                                                3         NaN
# 86                                                2         NaN
# 87                                              (.)         NaN
# 88                                              102         NaN
# 89                                              (.)         NaN
# 90                                                6         NaN
# 91                                                1         NaN
# 92                                              126         NaN
# 93                                              117         NaN
# 94                                              (.)         NaN
# 95                                                1         NaN
# 96                                              (.)         NaN
# 97                                                6         NaN
# 98                                                8         NaN
# 99                                              374         NaN
# 100                                             334         NaN
# 101                                              35         NaN
# 102                                              12         NaN
# 103                                               1         NaN
# 104                                               2         NaN
# 105                                              12         NaN
# 106                                               8         NaN
# 107                                               9         NaN
# 108                                               1         NaN
# 109                                               1         NaN
# 110                                               2         NaN
# 111                                             (.)         NaN
# 112                                               7         NaN
# 113                                             (.)         NaN
# 114                                              ..         NaN
# 115                                               1         NaN
# 116                                               1         NaN
# 117                                             (.)         NaN
# 118                                             (.)         NaN
# 119                                               1         NaN
# 120                                               5         NaN
#
#     Conventional arms transfersb(1990 prices) Imports (US$ millions) 1996  \
# 71                                                  ..
# 72                                                 611
# 73                                                   4
# 74                                                   0
# 75                                               1,274
# 76                                                  ..
# 77                                                 104
# 78                                               1,510
# 79                                                   0
# 80                                                  76
# 81                                                 138
# 82                                                  20
# 83                                                  29
# 84                                                  32
# 85                                                  56
# 86                                                   0
# 87                                                  ..
# 88                                                 630
# 89                                                   2
# 90                                                   0
# 91                                                   0
# 92                                                   0
# 93                                                 152
# 94                                                   0
# 95                                                   0
# 96                                                   0
# 97                                                   3
# 98                                                  87
# 99                                                 207
# 100                                                  9
# 101                                                435
# 102                                                 21
# 103                                                  0
# 104                                                 ..
# 105                                                  0
# 106                                                986
# 107                                                  0
# 108                                                 ..
# 109                                                 ..
# 110                                                  0
# 111                                                  0
# 112                                                  0
# 113                                                  0
# 114                                                 ..
# 115                                                 38
# 116                                                  0
# 117                                                 ..
# 118                                                 29
# 119                                                  0
# 120                                                 86
#
#     Reference 4   2006 Reference 5  \
# 71          NaN     ..         NaN
# 72          NaN     47         NaN
# 73          NaN      0         NaN
# 74          NaN      0         NaN
# 75          NaN  3,261         NaN
# 76          NaN     ..         NaN
# 77          NaN      0         NaN
# 78          NaN    454         NaN
# 79          NaN      0         NaN
# 80          NaN    117         NaN
# 81          NaN    365         NaN
# 82          NaN      0         NaN
# 83          NaN      0         NaN
# 84          NaN     43         NaN
# 85          NaN     16         NaN
# 86          NaN      0         NaN
# 87          NaN     ..         NaN
# 88          NaN    891         NaN
# 89          NaN      0         NaN
# 90          NaN      0         NaN
# 91          NaN      0         NaN
# 92          NaN      0         NaN
# 93          NaN     20         NaN
# 94          NaN      0         NaN
# 95          NaN     25         NaN
# 96          NaN      0         NaN
# 97          NaN      0         NaN
# 98          NaN    173         NaN
# 99          NaN    179         NaN
# 100         NaN      0         NaN
# 101         NaN     54         NaN
# 102         NaN      9         NaN
# 103         NaN      0         NaN
# 104         NaN     ..         NaN
# 105         NaN      0         NaN
# 106         NaN    526         NaN
# 107         NaN      0         NaN
# 108         NaN     ..         NaN
# 109         NaN     ..         NaN
# 110         NaN      1         NaN
# 111         NaN     26         NaN
# 112         NaN      0         NaN
# 113         NaN     63         NaN
# 114         NaN     ..         NaN
# 115         NaN    862         NaN
# 116         NaN     13         NaN
# 117         NaN     ..         NaN
# 118         NaN      0         NaN
# 119         NaN      0         NaN
# 120         NaN     49         NaN
#
#     Conventional arms Exports US$ millions  2006 Reference 6  \
# 71                                            ..         NaN
# 72                                             0         NaN
# 73                                            ..         NaN
# 74                                            ..         NaN
# 75                                           564         NaN
# 76                                            ..         NaN
# 77                                            ..         NaN
# 78                                            45         NaN
# 79                                            ..         NaN
# 80                                            13         NaN
# 81                                             0         NaN
# 82                                             0         NaN
# 83                                            ..         NaN
# 84                                            ..         NaN
# 85                                            ..         NaN
# 86                                            ..         NaN
# 87                                            ..         NaN
# 88                                             9         NaN
# 89                                            ..         NaN
# 90                                             0         NaN
# 91                                            ..         NaN
# 92                                            ..         NaN
# 93                                            ..         NaN
# 94                                            ..         NaN
# 95                                            ..         NaN
# 96                                            ..         NaN
# 97                                            ..         NaN
# 98                                            ..         NaN
# 99                                            ..         NaN
# 100                                           ..         NaN
# 101                                            8         NaN
# 102                                            3         NaN
# 103                                           ..         NaN
# 104                                            0         NaN
# 105                                            0         NaN
# 106                                            0         NaN
# 107                                            0         NaN
# 108                                           ..         NaN
# 109                                           ..         NaN
# 110                                            0         NaN
# 111                                           ..         NaN
# 112                                           ..         NaN
# 113                                           ..         NaN
# 114                                           ..         NaN
# 115                                          115         NaN
# 116                                           ..         NaN
# 117                                           ..         NaN
# 118                                           ..         NaN
# 119                                           ..         NaN
# 120                                           ..         NaN
#
#     Shared\n(%)  2002-06 Total armed forces Thousands2007 Reference 7  \
# 71                    ..                               ..         NaN
# 72                   (.)                              307         NaN
# 73                    ..                               25         NaN
# 74                    ..                                1         NaN
# 75                     2                            2,255         NaN
# 76                    ..                               ..         NaN
# 77                    ..                               44         NaN
# 78                   (.)                              515         NaN
# 79                    ..                                2         NaN
# 80                   (.)                              101         NaN
# 81                   (.)                               80         NaN
# 82                   (.)                               72         NaN
# 83                    ..                               57         NaN
# 84                    ..                              106         NaN
# 85                    ..                               35         NaN
# 86                    ..                                4         NaN
# 87                    ..                               ..         NaN
# 88                   (.)                              545         NaN
# 89                    ..                               10         NaN
# 90                   (.)                               11         NaN
# 91                    ..                                1         NaN
# 92                    ..                               67         NaN
# 93                    ..                              151         NaN
# 94                    ..                               ..         NaN
# 95                    ..                                3         NaN
# 96                    ..                                1         NaN
# 97                    ..                               16         NaN
# 98                    ..                              138         NaN
# 99                    ..                              455         NaN
# 100                   ..                               ..         NaN
# 101                  (.)                              302         NaN
# 102                  (.)                              308         NaN
# 103                   ..                               26         NaN
# 104                  (.)                               14         NaN
# 105                  (.)                                7         NaN
# 106                  (.)                              469         NaN
# 107                    1                               55         NaN
# 108                   ..                                9         NaN
# 109                   ..                               12         NaN
# 110                  (.)                               13         NaN
# 111                   ..                               46         NaN
# 112                   ..                               16         NaN
# 113                   ..                                5         NaN
# 114                   ..                               ..         NaN
# 115                  (.)                               62         NaN
# 116                   ..                                8         NaN
# 117                   ..                               ..         NaN
# 118                   ..                                9         NaN
# 119                   ..                                9         NaN
# 120                   ..                              201         NaN
#
#     Total armed forces Index (1985 = 100)2007
# 71                                         ..
# 72                                        130
# 73                                        113
# 74                                        167
# 75                                         58
# 76                                         ..
# 77                                         ..
# 78                                         82
# 79                                        100
# 80                                        144
# 81                                         63
# 82                                        414
# 83                                        134
# 84                                         92
# 85                                        100
# 86                                        148
# 87                                         ..
# 88                                         89
# 89                                         69
# 90                                         ..
# 91                                         15
# 92                                         ..
# 93                                        699
# 94                                         ..
# 95                                        143
# 96                                         13
# 97                                         38
# 98                                         81
# 99                                         44
# 100                                        ..
# 101                                       109
# 102                                        77
# 103                                        ..
# 104                                        22
# 105                                        ..
# 106                                       105
# 107                                        ..
# 108                                        27
# 109                                        72
# 110                                        ..
# 111                                       167
# 112                                        50
# 113                                       208
# 114                                        ..
# 115                                        58
# 116                                        ..
# 117                                        ..
# 118                                       225
# 119                                        ..
# 120                                       135

# %%
#Enregistrer les informations autres que les données contenues dans le dataframe

df_notes = df.iloc[121:124,]
df_src = df.iloc[124:125,]

df_notes = df_notes.dropna(how = 'any', axis = 1).reset_index(drop=True)
df_src = df_src.dropna(how = 'any', axis = 1).reset_index(drop=True)

df_notes
df_src
# Out:
# Empty DataFrame
# Columns: [HDI rank, Country, Internally displaced peoplea(thousands)2006e , Reference 1, Refugees By country of asylum(thousands)2006e, Reference 2, Refugees By country of originc(thousands) 2006e, Reference 3, Conventional arms transfersb(1990 prices) Imports (US$ millions) 1996, Reference 4, 2006, Reference 5, Conventional arms Exports US$ millions  2006, Reference 6, Shared
# (%)  2002-06, Total armed forces Thousands2007, Reference 7, Total armed forces Index (1985 = 100)2007]
# Index: []

# %%
df_notes
# Out:
# Empty DataFrame
# Columns: [HDI rank, Country, Internally displaced peoplea(thousands)2006e , Reference 1, Refugees By country of asylum(thousands)2006e, Reference 2, Refugees By country of originc(thousands) 2006e, Reference 3, Conventional arms transfersb(1990 prices) Imports (US$ millions) 1996, Reference 4, 2006, Reference 5, Conventional arms Exports US$ millions  2006, Reference 6, Shared
# (%)  2002-06, Total armed forces Thousands2007, Reference 7, Total armed forces Index (1985 = 100)2007]
# Index: []

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
df.loc[:, "HDI category"] = np.where(df["HDI rank"] < 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] < 70,
                                              "MEDIUM HUMAN DEVELOPMENT",
                                              "HIGH HUMAN DEVELOPMENT"
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-86cfab049c83> in <module>()
#       1 hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
#       2 df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
# ----> 3 df.loc[:, "HDI category"] = np.where(df["HDI rank"] < 155,
#       4                                      "LOW HUMAN DEVELOPMENT",
#       5                                      np.where(df["HDI rank"] < 70,
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1141
#    1142         elif is_object_dtype(x.dtype):
# -> 1143             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1144
#    1145         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1120         result = libops.vec_compare(x, y, op)
#    1121     else:
# -> 1122         result = libops.scalar_compare(x, y, op)
#    1123     return result
#    1124
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
